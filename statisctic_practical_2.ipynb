# %% [markdown]
# <a href="https://colab.research.google.com/github/Lathakh/2.Logistic-Regression-on-churn-modelling/blob/main/statisctic_practical_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
data=[23,24,32,45,12,43,67,45,32,56,32]

# %%
data
# Out:
# [23, 24, 32, 45, 12, 43, 67, 45, 32, 56, 32]

# %%
data_copy=data.copy()

# %%
data_copy
# Out:
# [23, 24, 32, 45, 12, 43, 67, 45, 32, 56, 32]

# %%
import seaborn as sns
sns.histplot(data,kde=True)
# Out:
# <Axes: ylabel='Count'>

# %%
data_copy.sort()

# %%
data_copy
# Out:
# [12, 23, 24, 32, 32, 32, 43, 45, 45, 56, 67]

# %%
data_copy.append(179)

# %%
data_copy.append(210)
data_copy.append(290)

# %%
data_copy
# Out:
# [12, 23, 24, 32, 32, 32, 43, 45, 45, 56, 67, 179, 210, 290]

# %%
import seaborn as sns
sns.histplot(data_copy,kde=True)
# Out:
# <Axes: ylabel='Count'>

# %%
data # raw data
# Out:
# [23, 24, 32, 45, 12, 43, 67, 45, 32, 56, 32]

# %%
data_copy # this is right skwed data
# Out:
# [12, 23, 24, 32, 32, 32, 43, 45, 45, 56, 67, 179, 210, 290]

# %%
# left skewed data
data_copy2=data.copy()

# %%
data_copy2
# Out:
# [23, 24, 32, 45, 12, 43, 67, 45, 32, 56, 32]

# %%
data_copy2.insert(0,-10)

# %%
data_copy2.insert(0,-75)

# %%
data_copy2
# Out:
# [-75, -10, 23, 24, 32, 45, 12, 43, 67, 45, 32, 56, 32]

# %%
sns.histplot(data_copy2,kde=True)
# Out:
# <Axes: ylabel='Count'>

# %%
import pandas as pd
data2=pd.read_csv("iris.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-26-788ebb50eaec> in <cell line: 2>()
#       1 import pandas as pd
# ----> 2 data2=pd.read_csv("iris.csv")
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...

# %%
data2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-eff1098d818d> in <cell line: 1>()
# ----> 1 data2
#
# NameError: name 'data2' is not defined

# %%
data2["sepal_length"]

# %%
sns.histplot(data2["sepal_length"],kde=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-657db7caf79f> in <cell line: 1>()
# ----> 1 sns.histplot(data2["sepal_length"],kde=True)
#
# NameError: name 'data2' is not defined

# %%
sns.histplot(data2["sepal_width"],kde=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-397f4aec2925> in <cell line: 1>()
# ----> 1 sns.histplot(data2["sepal_width"],kde=True)
#
# NameError: name 'data2' is not defined

# %%
sns.histplot(data2["petal_length"],kde=True)# bi model curve outlier
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-ef514fa84e10> in <cell line: 1>()
# ----> 1 sns.histplot(data2["petal_length"],kde=True)# bi model curve outlier
#
# NameError: name 'data2' is not defined

# %%
sns.histplot(data2["petal_width"],kde=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-538a38a8767e> in <cell line: 1>()
# ----> 1 sns.histplot(data2["petal_width"],kde=True)
#
# NameError: name 'data2' is not defined

# %%
import numpy as np              #mean=0.5, std divation=0.3
normal_distribution_data=np.random.normal(0.5,0.2,100)

# %%
normal_distribution_data
# Out:
# array([0.67486438, 0.61575325, 0.50572861, 0.34635599, 0.29297009,
#        0.64431741, 0.42750678, 0.28032598, 0.28457633, 0.60164346,
#        0.17901833, 0.13877937, 0.34830403, 0.39872192, 0.19272604,
#        0.55220029, 0.35037705, 0.53493391, 0.28967504, 0.37175494,
#        0.37358899, 0.37734666, 0.24720502, 0.57086553, 0.89385124,
#        0.29818031, 0.15085692, 0.55894421, 0.45277034, 0.67034705,
#        0.39720517, 0.69315696, 0.89408491, 0.23670377, 0.55982734,
#        0.51834737, 0.42871141, 0.9555116 , 0.75561043, 0.15060488,
#        0.27589353, 0.66858255, 0.47198409, 0.68678046, 0.29639367,
#        0.21134775, 0.61077426, 0.09770886, 0.35062742, 0.54220832,
#        0.11576251, 0.41894001, 0.43765248, 0.49487598, 0.54862657,
#        0.2137519 , 0.82911573, 0.60631016, 0.35124169, 0.43488317,
#        0.81121193, 0.32270458, 0.26733775, 0.62969898, 0.6545794 ,
#        0.73164785, 0.58141206, 0.28849347, 0.70829594, 0.73241717,
# ...

# %%
normal_distribution_data.shape
# Out:
# (100,)

# %%
sns.histplot(normal_distribution_data,kde=True)
# Out:
# <Axes: ylabel='Count'>

# %%
#log normal data
log_normal_distribution=np.random.lognormal(3.0,1.0,1000)

# %% [markdown]
# how you are going convert log normal distribution to  standard normal distribution ?
#
# we are using np.log  --- sns.histplot(np.log(log_normal_distribution),kde=True)

# %%
sns.histplot(log_normal_distribution,kde=True)
# Out:
# <Axes: ylabel='Count'>

# %%
sns.histplot(np.log(log_normal_distribution),kde=True)
# Out:
# <Axes: ylabel='Count'>

# %%
np.log(log_normal_distribution)
# Out:
# array([ 3.65886545,  2.887241  ,  2.95009093,  2.14346737,  2.67739396,
#         3.78534085,  1.66532512,  3.20427169,  3.01695712,  3.07922608,
#         5.11835544,  3.87156149,  3.01453136,  4.46237182,  1.65251394,
#         1.24647239,  4.39771198,  2.71604502,  4.25813172,  1.78903707,
#         0.81093569,  2.43588492,  3.59213025,  3.23382169,  2.91238097,
#         3.97254733,  3.17726349,  3.35125911,  5.05180562,  2.73613074,
#         2.24304471,  3.34826295,  3.10475671,  3.55390952,  3.42112738,
#         2.17834982,  0.85838549,  3.21115762,  3.08277977,  3.93441914,
#         3.21027506,  2.48965451,  5.15744678,  4.12736327,  3.08098073,
#         3.65903427,  3.2879281 ,  2.87185774,  2.59759372,  4.92451912,
#         2.79134464,  3.95633458,  2.62257941,  3.11228358,  4.12329551,
#         3.14606915,  2.81800187,  2.7117721 ,  3.02111268,  2.3751894 ,
#         2.34618576,  4.48548333,  2.80654987,  3.73137856,  2.42005104,
# ...

# %% [markdown]
# If  know the distribution is log normal then you can apply log to that then you can convert data to normal distribution .but in real world data we have any type of distribution it can fall so inorder to find that distibution we are going to use Q-Q plot

# %%
#Q-Q plot quantile -quantile plot  (probabiliy plot)
#plot between theoritical(assumption of data and real value might be different) and real probability

# %%
#  to check the data is normal distribution or not

# %%
import matplotlib.pyplot as plt
import scipy.stats as stat
import pylab

def plot_data(sample):
  plt.figure(figsize=(10,6))
  plt.subplot(1,2,1)
  sns.histplot(sample,kde=True)
  plt.subplot(1,2,2)
  stat.probplot(sample,dist="norm",plot=pylab)
  plt.show()

# %%
plot_data(log_normal_distribution)

# %%
plot_data(np.log(log_normal_distribution))

# %%
#x-axis 25%, quantle data  y-axis -probability

# %% [markdown]
# probability distibution function
# 1. probability mass function -discrete probability distribution
#  -uniform
#  - bernoulii
#  - binomial
#  -poisson
#
# 2. pdf- continous probability distribution
#  - uniform
#  -normal(SND)
#  -lognormal
#  -pareto
#  -powerlaw(80-20 rule)

# %% [markdown]
# uniform distribution

# %%
from numpy import random
random.uniform(size=500)
# Out:
# array([8.72287001e-02, 1.04206048e-02, 9.81815583e-01, 8.13247681e-01,
#        5.44399810e-01, 1.95942984e-01, 6.04872140e-01, 2.88324572e-02,
#        9.89834776e-01, 3.52155607e-01, 6.10171456e-01, 8.66416652e-01,
#        9.33215308e-01, 6.24025253e-01, 1.51865532e-01, 2.32122794e-01,
#        6.42916380e-01, 2.02281015e-01, 8.49463798e-01, 8.22128539e-02,
#        6.68934080e-01, 8.51828391e-01, 1.66472247e-01, 4.44491166e-02,
#        6.75113321e-01, 2.55840348e-02, 3.53431606e-01, 7.40975578e-01,
#        7.12832799e-01, 8.35771671e-01, 8.09307150e-01, 6.43070933e-01,
#        9.80966644e-01, 6.21025249e-01, 1.71152687e-01, 3.28259365e-01,
#        2.46392930e-01, 1.98192381e-01, 3.50084341e-01, 4.57365137e-01,
#        6.95323892e-01, 9.98397461e-01, 5.00487618e-01, 7.53100315e-01,
#        4.95726822e-02, 4.64013129e-01, 5.54757926e-01, 3.76257431e-01,
#        9.88008202e-01, 1.01025108e-01, 6.72103772e-01, 9.76552852e-01,
# ...

# %%
sns.distplot(random.uniform(size=500),hist=False)
# Out:
# <ipython-input-47-217acc31d648>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.uniform(size=500),hist=False)
# <Axes: ylabel='Density'>

# %%
np.random.randint(1,8,size=800)
# Out:
# array([2, 4, 7, 5, 2, 2, 7, 2, 3, 5, 3, 6, 3, 6, 3, 3, 6, 6, 1, 7, 6, 1,
#        2, 1, 3, 3, 5, 2, 6, 2, 1, 2, 3, 5, 5, 4, 1, 6, 5, 4, 2, 6, 3, 7,
#        1, 6, 4, 4, 3, 7, 6, 4, 1, 3, 3, 3, 3, 1, 1, 2, 6, 6, 2, 6, 3, 4,
#        5, 6, 2, 1, 2, 3, 2, 5, 5, 1, 5, 4, 5, 7, 1, 7, 5, 3, 7, 2, 1, 6,
#        3, 2, 1, 5, 4, 2, 4, 4, 1, 5, 2, 7, 3, 2, 6, 1, 6, 7, 1, 4, 7, 5,
#        6, 7, 4, 6, 6, 6, 4, 1, 6, 7, 2, 6, 5, 4, 3, 5, 6, 7, 3, 6, 1, 2,
#        7, 5, 5, 5, 3, 1, 6, 6, 2, 7, 7, 3, 1, 5, 5, 3, 5, 1, 4, 5, 6, 4,
#        6, 5, 2, 4, 1, 1, 6, 5, 3, 4, 3, 4, 1, 1, 6, 7, 6, 6, 5, 4, 1, 2,
#        4, 1, 7, 6, 2, 5, 1, 6, 3, 6, 2, 6, 2, 3, 6, 4, 2, 2, 2, 3, 2, 5,
#        2, 3, 1, 1, 5, 3, 3, 3, 7, 2, 1, 4, 2, 5, 6, 4, 5, 1, 7, 3, 6, 4,
#        5, 5, 4, 1, 7, 4, 7, 7, 3, 6, 2, 5, 6, 1, 5, 3, 2, 6, 4, 3, 3, 6,
#        6, 7, 3, 1, 5, 4, 3, 5, 4, 5, 5, 3, 3, 3, 6, 6, 2, 7, 4, 7, 6, 7,
#        2, 4, 5, 4, 1, 7, 6, 7, 6, 1, 4, 5, 3, 4, 5, 7, 2, 1, 3, 5, 5, 3,
# ...

# %%
sns.histplot(np.random.randint(1,8,size=800))
# Out:
# <Axes: ylabel='Count'>

# %% [markdown]
# x- data ,y-frequency/count - distibution | x-data  ,y-probability distribution

# %% [markdown]
# Bernoulii distibution
#  we dont have method for this.

# %%
p=0.3
sample_size=1000
bernoulii_data=np.random.choice([0,1],size=sample_size,p=[1-p,p])
sns.histplot(bernoulii_data,bins=2,kde=False,color="yellow")
# Out:
# <Axes: ylabel='Count'>

# %%
n_trials=10
probability=0.6

data3=np.random.binomial(n_trials,probability,10000)

# %%
sns.distplot(data3)
# Out:
# <ipython-input-52-6b5eda17f777>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data3)
# <Axes: ylabel='Density'>

# %% [markdown]
# poisson distribution

# %%
poisson_data=np.random.poisson(lam=5,size=1000)

ax=sns.histplot(poisson_data,kde=False,color="green")
ax.set(xlabel="Poisson_distribution",ylabel="frequency")

plt.show()

# %% [markdown]
# lam - means that code is generating the random data point from posison distribution where average number of events or occures in specified interval is 5 here.

# %% [markdown]
# **central limit theorem**

# %%
population=np.random.randint(10,20,50)

# %%
population
# Out:
# array([12, 12, 16, 10, 17, 18, 19, 17, 11, 18, 16, 13, 17, 17, 12, 17, 17,
#        19, 10, 10, 12, 11, 10, 19, 16, 11, 15, 10, 18, 17, 16, 10, 17, 18,
#        10, 15, 11, 13, 19, 19, 11, 19, 15, 19, 16, 11, 11, 18, 13, 10])

# %%
np.mean(population)
# Out:
# 14.56

# %%
np.median(population)
# Out:
# 15.5

# %%
from statistics import mode
mode(population)
# Out:
# 10

# %%
#random sample from the population
sample=np.random.choice(population,20)

# %%
sample
# Out:
# array([19, 18, 18, 19, 10, 12, 10, 10, 17, 17, 18, 10, 16, 15, 12, 17, 10,
#        16, 10, 16])

# %%
print(f"mean of the sample is:{np.mean(sample)}")
print(f"median of the sample is:{np.median(sample)}")
print(f"mode of the sample is: {mode(sample)}")
# Out:
# mean of the sample is:14.5
# median of the sample is:16.0
# mode of the sample is: 10

# %% [markdown]
# Irrespective of population mean,  mean  of smaple is normally distributed
#
#                  or
# .**suppose you have population with any shape of probability distribution (not neccesarily normal) , and you drawn random sample of fixed size from this population.As the sample increase size, the distribution of the sample means approaches a normal distribution,regardless of the shape of the population distribution**

# %%
sample1=np.random.choice(population,20)
sample2=np.random.choice(population,20)
sample3=np.random.choice(population,20)
sample4=np.random.choice(population,20)

# %%
print(sample1)
print(60*"=")
print(sample2)
print(60*"=")
print(sample3)
print(60*"=")
print(sample4)
print(60*"=")
# Out:
# [17 17 16 10 13 19 19 11 12 10 11 11 10 11 17 17 15 17 10 10]
# ...
# [18 19 17 17 11 11 16 18 16 17 10 18 11 10 12 13 16 10 18 11]
# ...
# [13 19 18 16 16 13 15 16 17 18 11 10 19 13 10 11 18 12 12 17]
# ...
# [13 10 19 17 13 19 18 16 16 18 10 10 19 11 10 17 11 11 17 18]
# ...

# %%
mean_of_sample=[]
all_sample=[sample1,sample2,sample3,sample4]
for sample in all_sample:
  print(np.mean(sample))
  mean_of_sample.append(np.mean(sample))
# Out:
# 13.65
# 14.45
# 14.7
# 14.65

# %%
mean_of_sample.append(np.mean(sample))

# %%
import numpy as np

# %%
population=np.random.binomial(10,0.5,10000)

# %%
population
# Out:
# array([6, 5, 4, ..., 3, 5, 5])

# %%
len(population)
# Out:
# 10000

# %%
sns.distplot(population)
# Out:
# <ipython-input-83-8d1caca3cc70>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(population)
# <Axes: ylabel='Density'>

# %%
size=int(len(population)*0.45)
size
# Out:
# 4500

# %%
sample_mean=[]

for i in range(1,31):
  np.random.choice(population,size=size)
  sample_mean.append(np.mean(sample))

# %%
sample_mean
# Out:
# [14.65,
#  14.65,
#  14.65,
#  14.65,
#  14.65,
#  14.65,
#  14.65,
#  14.65,
#  14.65,
#  14.65,
#  14.65,
#  14.65,
#  14.65,
#  14.65,
#  14.65,
#  14.65,
#  14.65,
#  14.65,
#  14.65,
#  14.65,
#  14.65,
#  14.65,
#  14.65,
#  14.65,
#  14.65,
#  14.65,
#  14.65,
#  14.65,
#  14.65,
#  14.65]

# %%
sns.distplot(sample_mean)
# Out:
# <ipython-input-97-d196905dea46>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(sample_mean)
# /usr/local/lib/python3.10/dist-packages/seaborn/distributions.py:2511: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   kdeplot(**{axis: a}, ax=ax, color=kde_color, **kde_kws)
# <Axes: ylabel='Density'>
